# %%
import tinydb
from tinydb import TinyDB, Query

# %%
db = TinyDB('lala.json')

# %%
db.insert({'type': 'apple', 'count': 7})
# Out:
# 1

# %%
db.insert({'train_loss': [1, 2, 3,4 ,5 ]})
# Out:
# 2

# %%
db.insert({'val_loss': [2,3,4,5,6]})
# Out:
# 3

# %%
db.all()
# Out:
# [{'type': 'apple', 'count': 7},
#  {'train_loss': [1, 2, 3, 4, 5]},
#  {'val_loss': [2, 3, 4, 5, 6]}]

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %%
fig, ax = plt.subplots()
ax.plot([1,2,3,4,7])
ax.plot([2,4,3,5,4,6,])

# %%
from io import BytesIO
from base64 import b64encode

# %%
s = BytesIO()
fig.canvas.print_png(s)
s.seek(0)
s64 = b64encode(s.read()).decode()

# %%
db.insert({'fig': s64})
# Out:
# 5

# %%
db.all()
# Out:
# [{'type': 'apple', 'count': 7},
#  {'train_loss': [1, 2, 3, 4, 5]},
#  {'val_loss': [2, 3, 4, 5, 6]},
#  {'fig': '...'}]

# %%
import argparse
parser = argparse.ArgumentParser(description='Train a new model.')
parser.add_argument('--title', type=str, default="", 
                    help='short title of model')
parser.add_argument('--subset_size', type=int, default=0, 
                    help='Use only a subset of data for training')
parser.add_argument('--learning_rate', type=float, default=0.001, 
                    help='learning rate (default 0.001)')
parser.add_argument('--epochs', type=int, default=10, 
                    help='number of epochs for training (default 10)')
parser.add_argument('--batch_size', type=int, default=10, 
                    help='batch size (default 10)')

parser.add_argument('--save_dir', type=str, default="runs", 
                    help='path to directory where trained model checkpoints should be saved')
# Out:
# _StoreAction(option_strings=['--save_dir'], dest='save_dir', nargs=None, const=None, default='runs', type=<class 'str'>, choices=None, help='path to directory where trained model checkpoints should be saved', metavar=None)

# %%
ns = parser.parse_known_args()[0]

# %%
r, _ = parser.parse_known_args()

# %%
type(r)
# Out:
# argparse.Namespace

# %%
r._get_kwargs()
# Out:
# [('batch_size', 10),
#  ('epochs', 10),
#  ('learning_rate', 0.001),
#  ('save_dir', 'runs'),
#  ('subset_size', 0),
#  ('title', '')]

# %%
r.__dict__
# Out:
# {'title': '',
#  'subset_size': 0,
#  'learning_rate': 0.001,
#  'epochs': 10,
#  'batch_size': 10,
#  'save_dir': 'runs'}

# %%
getattr(r, 'epochs')
# Out:
# 10

# %%
import datetime

# %%
now = datetime.datetime.now()

# %%
now.isoformat()
# Out:
# '2020-06-20T12:00:55.063232'

# %%
vars(r)
# Out:
# {'title': '',
#  'subset_size': 0,
#  'learning_rate': 0.001,
#  'epochs': 10,
#  'batch_size': 10,
#  'save_dir': 'runs'}
